# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame([12,52,96,89,36,25,45],columns=['Age'])
df.plot.hist(bins=20,edgecolor='k')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
